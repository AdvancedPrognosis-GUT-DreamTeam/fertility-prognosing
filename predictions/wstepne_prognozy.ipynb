# %%
import pandas as pd
from sklearn.linear_model import LinearRegression
from statsmodels.tsa.arima.model import ARIMA
import numpy as np
import matplotlib.pyplot as plt
from pmdarima import auto_arima

# %%
import warnings
warnings.filterwarnings("ignore", message="Maximum Likelihood optimization failed to")
warnings.filterwarnings("ignore", category=UserWarning)

# %%
df = pd.read_csv('data\wdi_fertility_data_prepped.csv')

# %%
df.head()
# Out:
#    Unnamed: 0  year year_code country_name country_code  total_fertility_rate  \
# 0         160  1990    YR1990    Argentina          ARG                 3.034
# 1         161  1990    YR1990       Brazil          BRA                 2.905
# 2         162  1990    YR1990       France          FRA                 1.770
# 3         163  1990    YR1990      Germany          DEU                 1.450
# 4         164  1990    YR1990       Poland          POL                 2.060
#
#    gdp_2015_dollar  gdp_per_capita_2015_dollar  gdp_growth  \
# 0     2.660000e+11                 8144.494294   -2.467214
# 1     9.170000e+11                 6086.077553   -4.350000
# 2     1.660000e+12                28617.443570    2.923935
# 3     2.340000e+12                29485.709970    5.255006
# 4     1.950000e+11                 5111.345330         NaN
#
#    physicians_per_1000  hospital_beds_per_1000  \
# 0                2.680                  4.5943
# 1                1.074                  3.3453
# 2                3.118                  9.7000
# 3                  NaN                 10.4000
# 4                2.145                  5.7000
#
#    arable_land_hectare_per_person        cpi  crop_production_index  \
# 0                        0.814243        NaN                  39.14
# 1                        0.314121   0.000893                  41.03
# 2                        0.306398  71.188126                  98.60
# 3                        0.150706  67.475110                  89.56
# 4                        0.377531   6.983705                 128.14
#
#    food_production_index  percent_of_household_expenditure_in_gdp  \
# 0                  50.98                                77.139373
# 1                  38.46                                59.302498
# 2                 101.62                                55.205943
# 3                  99.54                                56.346298
# 4                 116.13                                      NaN
#
#    life_expectancy_at_birth  infant_mortality_rate  child_mortality_rate  \
# 0                 71.784000                   25.4                  28.8
# 1                 65.985000                   52.5                  63.0
# 2                 76.600000                    7.5                   9.0
# 3                 75.085634                    7.0                   8.5
# 4                 70.890244                   15.2                  17.4
#
#    female_percentage_in_labor
# 0                      29.110
# 1                      44.951
# 2                      46.701
# 3                      45.355
# 4                         NaN

# %%
df.shape
# Out:
# (320, 20)

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'year', 'year_code', 'country_name', 'country_code',
#        'total_fertility_rate', 'gdp_2015_dollar', 'gdp_per_capita_2015_dollar',
#        'gdp_growth', 'physicians_per_1000', 'hospital_beds_per_1000',
#        'arable_land_hectare_per_person', 'cpi', 'crop_production_index',
#        'food_production_index', 'percent_of_household_expenditure_in_gdp',
#        'life_expectancy_at_birth', 'infant_mortality_rate',
#        'child_mortality_rate', 'female_percentage_in_labor'],
#       dtype='object')

# %%
df.country_name.unique()
# Out:
# array(['Argentina', 'Brazil', 'France', 'Germany', 'Poland', 'Nigeria',
#        'Kenya', 'United Kingdom', 'China', 'Japan'], dtype=object)

# %% [markdown]
# ### Prognozy

# %%
# Lista zmiennych 
variables = [
    'total_fertility_rate', 'gdp_2015_dollar', 'gdp_per_capita_2015_dollar',
    'gdp_growth', 'physicians_per_1000', 'hospital_beds_per_1000',
    'arable_land_hectare_per_person', 'cpi', 'crop_production_index',
    'food_production_index', 'percent_of_household_expenditure_in_gdp',
    'life_expectancy_at_birth', 'infant_mortality_rate',
    'child_mortality_rate', 'female_percentage_in_labor'
]


# Liczba lat do prognozy
forecast_years = 5

# %%
arima_models_info = {}

countries = df['country_name'].unique()
results = []

for country in countries:
    country_data = df[df['country_name'] == country].sort_values(by='year')
    max_year = country_data['year'].max()
    
    for year_offset in range(1, forecast_years + 1):
        forecast_year = max_year + year_offset
        row = {'country_name': country, 'year': forecast_year}
        
        for var in variables:
            variable_data = country_data[['year', var]].dropna()
            X = variable_data['year'].values.reshape(-1, 1)
            y = variable_data[var].values
            
            # Jeśli brak danych
            if len(y) < 2:
                row[f'{var}_Linear Regression'] = None
                row[f'{var}_ARIMA'] = None
                arima_models_info[(country, var)] = 'Brak danych do modelowania'
                continue
            
            # Regresja Liniowa
            lin_reg = LinearRegression()
            lin_reg.fit(X, y)
            row[f'{var}_Linear Regression'] = lin_reg.predict([[forecast_year]])[0]
            
            # ARIMA
            try:
                arima_model = auto_arima(y, seasonal=False, trace=False, error_action='ignore', suppress_warnings=True)
                best_order = arima_model.order
                arima_models_info[(country, var)] = f'ARIMA({best_order[0]}, {best_order[1]}, {best_order[2]})'
                
                forecast_value = arima_model.predict(n_periods=year_offset)[-1]
                row[f'{var}_ARIMA'] = forecast_value
            except Exception as e:
                row[f'{var}_ARIMA'] = None
                arima_models_info[(country, var)] = f'Błąd: {str(e)}'
        
        results.append(row)

# %%
forecast_df = pd.DataFrame(results)
display(forecast_df)
# Out:
#       country_name  year  total_fertility_rate_Linear Regression  \
# 0        Argentina  2022                                1.930744
# 1        Argentina  2023                                1.897846
# 2        Argentina  2024                                1.864948
# 3        Argentina  2025                                1.832050
# 4        Argentina  2026                                1.799152
# 5           Brazil  2022                                1.434903
# 6           Brazil  2023                                1.395164
# 7           Brazil  2024                                1.355426
# 8           Brazil  2025                                1.315687
# 9           Brazil  2026                                1.275948
# 10          France  2022                                1.991351
# 11          France  2023                                1.998043
# 12          France  2024                                2.004734
# 13          France  2025                                2.011426
# 14          France  2026                                2.018118
# 15         Germany  2022                                1.539919
# 16         Germany  2023                                1.548532
# 17         Germany  2024                                1.557144
# 18         Germany  2025                                1.565757
# 19         Germany  2026                                1.574370
# 20          Poland  2022                                1.197581
# 21          Poland  2023                                1.181582
# 22          Poland  2024                                1.165583
# 23          Poland  2025                                1.149584
# 24          Poland  2026                                1.133585
# 25         Nigeria  2022                                5.405230
# 26         Nigeria  2023                                5.371266
# 27         Nigeria  2024                                5.337303
# 28         Nigeria  2025                                5.303340
# 29         Nigeria  2026                                5.269376
# 30           Kenya  2022                                3.278387
# 31           Kenya  2023                                3.194882
# 32           Kenya  2024                                3.111377
# 33           Kenya  2025                                3.027872
# 34           Kenya  2026                                2.944367
# 35  United Kingdom  2022                                1.745302
# 36  United Kingdom  2023                                1.744582
# 37  United Kingdom  2024                                1.743862
# 38  United Kingdom  2025                                1.743141
# 39  United Kingdom  2026                                1.742421
# 40           China  2022                                1.510381
# 41           China  2023                                1.501671
# 42           China  2024                                1.492961
# 43           China  2025                                1.484251
# 44           China  2026                                1.475542
# 45           Japan  2022                                1.346089
# 46           Japan  2023                                1.343371
# 47           Japan  2024                                1.340652
# 48           Japan  2025                                1.337934
# 49           Japan  2026                                1.335216
#
#     total_fertility_rate_ARIMA  gdp_2015_dollar_Linear Regression  \
# 0                     1.832769                       6.355585e+11
# 1                     1.800071                       6.461794e+11
# 2                     1.762982                       6.568004e+11
# 3                     1.725893                       6.674214e+11
# 4                     1.688805                       6.780423e+11
# 5                     1.637691                       1.998131e+12
# 6                     1.636728                       2.033012e+12
# 7                     1.638110                       2.067893e+12
# 8                     1.641838                       2.102774e+12
# 9                     1.647912                       2.137655e+12
# 10                    1.840000                       2.684798e+12
# 11                    1.840000                       2.716358e+12
# 12                    1.840000                       2.747918e+12
# 13                    1.840000                       2.779478e+12
# 14                    1.840000                       2.811037e+12
# 15                    1.580000                       3.632278e+12
# 16                    1.580000                       3.671204e+12
# 17                    1.580000                       3.710130e+12
# 18                    1.580000                       3.749056e+12
# 19                    1.580000                       3.787982e+12
# 20                    1.275426                       5.775685e+11
# 21                    1.217908                       5.909610e+11
# 22                    1.161988                       6.043534e+11
# 23                    1.105200                       6.177458e+11
# 24                    1.048883                       6.311382e+11
# 25                    5.173369                       5.476069e+11
# 26                    5.119683                       5.620660e+11
# 27                    5.071612                       5.765251e+11
# 28                    5.026711                       5.909842e+11
# 29                    4.983601                       6.054434e+11
# 30                    3.267110                       8.260028e+10
# 31                    3.190522                       8.452449e+10
# 32                    3.106841                       8.644869e+10
# 33                    3.018460                       8.837289e+10
# 34                    2.927338                       9.029710e+10
# 35                    1.570123                       3.242319e+12
# 36                    1.598898                       3.288387e+12
# 37                    1.643714                       3.334456e+12
# 38                    1.700057                       3.380524e+12
# 39                    1.762306                       3.426593e+12
# 40                    1.078398                       1.417621e+13
# 41                    1.051849                       1.465515e+13
# 42                    1.062904                       1.513408e+13
# 43                    1.111956                       1.561302e+13
# 44                    1.187402                       1.609196e+13
# 45                    1.282198                       4.637641e+12
# 46                    1.286637                       4.668862e+12
# 47                    1.297024                       4.700082e+12
# 48                    1.306531                       4.731303e+12
# 49                    1.315234                       4.762524e+12
#
#     gdp_2015_dollar_ARIMA  gdp_per_capita_2015_dollar_Linear Regression  \
# 0            5.798065e+11                                  14104.620851
# 1            5.896129e+11                                  14256.721314
# 2            5.994194e+11                                  14408.821776
# 3            6.092258e+11                                  14560.922239
# 4            6.190323e+11                                  14713.022702
# 5            1.869774e+12                                   9306.615149
# 6            1.899548e+12                                   9412.846558
# 7            1.929323e+12                                   9519.077967
# 8            1.959097e+12                                   9625.309376
# 9            1.988871e+12                                   9731.540785
# 10           2.609677e+12                                  39416.005487
# 11           2.639355e+12                                  39737.699100
# 12           2.669032e+12                                  40059.392712
# 13           2.698710e+12                                  40381.086324
# 14           2.728387e+12                                  40702.779937
# 15           3.609677e+12                                  44014.062074
# 16           3.649355e+12                                  44467.983442
# 17           3.689032e+12                                  44921.904810
# 18           3.728710e+12                                  45375.826178
# 19           3.768387e+12                                  45829.747546
# 20           6.317134e+11                                  15230.680958
# 21           6.652017e+11                                  15587.022139
# 22           6.985945e+11                                  15943.363320
# 23           7.319991e+11                                  16299.704501
# 24           7.654022e+11                                  16656.045682
# 25           5.297742e+11                                   2749.261159
# 26           5.415484e+11                                   2794.545801
# 27           5.533226e+11                                   2839.830443
# 28           5.650968e+11                                   2885.115085
# 29           5.768710e+11                                   2930.399726
# 30           9.679250e+10                                   1567.610570
# 31           1.031712e+11                                   1581.591129
# 32           1.095499e+11                                   1595.571687
# 33           1.159285e+11                                   1609.552246
# 34           1.223072e+11                                   1623.532804
# 35           3.122258e+12                                  48816.009252
# 36           3.164516e+12                                  49341.092019
# 37           3.206774e+12                                  49866.174786
# 38           3.249032e+12                                  50391.257554
# 39           3.291290e+12                                  50916.340321
# 40           1.720000e+13                                  10180.227586
# 41           1.850000e+13                                  10515.471157
# 42           1.980000e+13                                  10850.714729
# 43           2.110000e+13                                  11185.958300
# 44           2.240000e+13                                  11521.201872
# 45           4.521613e+12                                  36301.685606
# 46           4.553226e+12                                  36530.173862
# 47           4.584839e+12                                  36758.662119
# 48           4.616452e+12                                  36987.150376
# 49           4.648065e+12                                  37215.638633
#
#     gdp_per_capita_2015_dollar_ARIMA  gdp_growth_Linear Regression  \
# 0                       12444.318270                      0.260150
# 1                       12444.318270                      0.123668
# 2                       12444.318270                     -0.012814
# 3                       12444.318270                     -0.149296
# 4                       12444.318270                     -0.285778
# 5                        8684.348171                      1.547865
# 6                        8765.544128                      1.514008
# 7                        8846.740084                      1.480152
# 8                        8927.936041                      1.446296
# 9                        9009.131998                      1.412440
# 10                      38304.928133                      0.711195
# 11                      38607.662025                      0.663631
# 12                      38910.395918                      0.616066
# 13                      39213.129810                      0.568502
# 14                      39515.863703                      0.520937
# 15                      43332.742280                      0.642182
# 16                      43765.462039                      0.589487
# 17                      44198.181799                      0.536792
# 18                      44630.901559                      0.484096
# 19                      45063.621318                      0.431401
# 20                      16504.135983                      4.130699
# 21                      16875.565198                      4.155875
# 22                      17274.637675                      4.181051
# 23                      18035.794389                      4.206228
# 24                      18562.414469                      4.231404
# 25                       2447.060982                      3.846480
# 26                       2457.813786                      3.817775
# 27                       2464.429993                      3.789070
# 28                       2468.500950                      3.760365
# 29                       2471.005812                      3.731660
# 30                       1741.241392                      5.438111
# 31                       1776.742395                      5.548303
# 32                       1812.243397                      5.658495
# 33                       1847.744400                      5.768688
# 34                       1883.245402                      5.878880
# 35                      46373.969152                      1.100615
# 36                      46858.327284                      1.057290
# 37                      47342.685416                      1.013964
# 38                      47827.043548                      0.970639
# 39                      48311.401680                      0.927313
# 40                      11577.280889                      6.885261
# 41                      12278.157521                      6.751560
# 42                      12784.544103                      6.617858
# 43                      13438.026493                      6.484156
# 44                      14023.064270                      6.350454
# 45                      35936.268501                     -0.116969
# 46                      36171.082731                     -0.181119
# 47                      36405.896962                     -0.245270
# 48                      36640.711193                     -0.309421
# 49                      36875.525423                     -0.373571
#
#     gdp_growth_ARIMA  ...  \
# 0           2.512104  ...
# 1           2.512104  ...
# 2           2.512104  ...
# 3           2.512104  ...
# 4           2.512104  ...
# 5           2.106493  ...
# 6           2.106493  ...
# 7           2.106493  ...
# 8           2.106493  ...
# 9           2.106493  ...
# 10          1.496008  ...
# 11          1.496008  ...
# 12          1.496008  ...
# 13          1.496008  ...
# 14          1.496008  ...
# 15          1.511655  ...
# 16          1.511655  ...
# 17          1.511655  ...
# 18          1.511655  ...
# 19          1.511655  ...
# 20          3.727876  ...
# 21          3.727876  ...
# 22          3.727876  ...
# 23          3.727876  ...
# 24          3.727876  ...
# 25          2.422226  ...
# 26          4.592938  ...
# 27          3.183918  ...
# 28          4.927345  ...
# 29          3.539495  ...
# 30          7.590489  ...
# 31          7.590489  ...
# 32          7.590489  ...
# 33          7.590489  ...
# 34          7.590489  ...
# 35          1.815486  ...
# 36          1.815486  ...
# 37          1.815486  ...
# 38          1.815486  ...
# 39          1.815486  ...
# 40         11.266174  ...
# 41         11.443804  ...
# 42         10.459418  ...
# 43          9.434257  ...
# 44          8.846474  ...
# 45          0.941516  ...
# 46          0.941516  ...
# 47          0.941516  ...
# 48          0.941516  ...
# 49          0.941516  ...
#
#     percent_of_household_expenditure_in_gdp_Linear Regression  \
# 0                                           62.040861
# 1                                           61.721144
# 2                                           61.401427
# 3                                           61.081710
# 4                                           60.761993
# 5                                           62.938806
# 6                                           62.977094
# 7                                           63.015382
# 8                                           63.053670
# 9                                           63.091958
# 10                                          53.746572
# 11                                          53.709085
# 12                                          53.671597
# 13                                          53.634110
# 14                                          53.596622
# 15                                          51.887863
# 16                                          51.712015
# 17                                          51.536166
# 18                                          51.360318
# 19                                          51.184469
# 20                                          58.215287
# 21                                          57.997692
# 22                                          57.780098
# 23                                          57.562503
# 24                                          57.344909
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
# 30                                          79.263484
# 31                                          79.571413
# 32                                          79.879343
# 33                                          80.187272
# 34                                          80.495202
# 35                                          62.199599
# 36                                          62.036689
# 37                                          61.873779
# 38                                          61.710869
# 39                                          61.547959
# 40                                          34.394888
# 41                                          33.993566
# 42                                          33.592243
# 43                                          33.190920
# 44                                          32.789598
# 45                                          56.923476
# 46                                          57.076240
# 47                                          57.229005
# 48                                          57.381770
# 49                                          57.534535
#
#     percent_of_household_expenditure_in_gdp_ARIMA  \
# 0                                       62.990083
# 1                                       62.990083
# 2                                       62.990083
# 3                                       62.990083
# 4                                       62.990083
# 5                                       61.707867
# 6                                       61.827070
# 7                                       60.360142
# 8                                       60.794469
# 9                                       61.388933
# 10                                      52.709959
# 11                                      52.833473
# 12                                      52.946562
# 13                                      53.050106
# 14                                      53.144909
# 15                                      49.132258
# 16                                      48.906819
# 17                                      48.681380
# 18                                      48.455942
# 19                                      48.230503
# 20                                      56.187773
# 21                                      56.187773
# 22                                      56.187773
# 23                                      56.187773
# 24                                      56.187773
# 25                                            NaN
# 26                                            NaN
# 27                                            NaN
# 28                                            NaN
# 29                                            NaN
# 30                                      75.153455
# 31                                      74.763491
# 32                                      74.447920
# 33                                      74.192550
# 34                                      73.985897
# 35                                      59.951341
# 36                                      59.951341
# 37                                      59.951341
# 38                                      59.951341
# 39                                      59.951341
# 40                                      38.058950
# 41                                      38.024566
# 42                                      38.002917
# 43                                      37.989288
# 44                                      37.980707
# 45                                      53.536611
# 46                                      53.536611
# 47                                      53.536611
# 48                                      53.536611
# 49                                      53.536611
#
#     life_expectancy_at_birth_Linear Regression  \
# 0                                    77.476185
# 1                                    77.636428
# 2                                    77.796670
# 3                                    77.956912
# 4                                    78.117155
# 5                                    76.101341
# 6                                    76.394125
# 7                                    76.686909
# 8                                    76.979692
# 9                                    77.272476
# 10                                   83.755901
# 11                                   83.971225
# 12                                   84.186550
# 13                                   84.401874
# 14                                   84.617198
# 15                                   82.156376
# 16                                   82.359718
# 17                                   82.563060
# 18                                   82.766403
# 19                                   82.969745
# 20                                   78.591444
# 21                                   78.824157
# 22                                   79.056870
# 23                                   79.289583
# 24                                   79.522296
# 25                                   53.836409
# 26                                   54.120716
# 27                                   54.405023
# 28                                   54.689330
# 29                                   54.973637
# 30                                   62.909454
# 31                                   63.173027
# 32                                   63.436600
# 33                                   63.700172
# 34                                   63.963745
# 35                                   82.144168
# 36                                   82.335668
# 37                                   82.527169
# 38                                   82.718669
# 39                                   82.910169
# 40                                   79.381435
# 41                                   79.723360
# 42                                   80.065284
# 43                                   80.407208
# 44                                   80.749132
# 45                                   85.080347
# 46                                   85.270302
# 47                                   85.460257
# 48                                   85.650212
# 49                                   85.840167
#
#     life_expectancy_at_birth_ARIMA  infant_mortality_rate_Linear Regression  \
# 0                        75.506323                                 6.680645
# 1                        75.622645                                 6.142540
# 2                        75.738968                                 5.604435
# 3                        75.855290                                 5.066331
# 4                        75.971613                                 4.528226
# 5                        71.491000                                 4.620565
# 6                        70.232000                                 3.333743
# 7                        68.973000                                 2.046921
# 8                        67.714000                                 0.760099
# 9                        66.455000                                -0.526723
# 10                       82.517960                                 2.188105
# 11                       82.700104                                 2.074505
# 12                       82.885162                                 1.960905
# 13                       83.069477                                 1.847306
# 14                       83.253982                                 1.733706
# 15                       81.005625                                 2.426210
# 16                       80.674321                                 2.318897
# 17                       80.649211                                 2.211584
# 18                       80.657056                                 2.104271
# 19                       80.406901                                 1.996957
# 20                       74.923596                                 1.375605
# 21                       74.421617                                 1.000073
# 22                       73.986297                                 0.624542
# 23                       73.608783                                 0.249010
# 24                       73.281400                                -0.126521
# 25                       52.506847                                64.823185
# 26                       52.371242                                62.865121
# 27                       52.262532                                60.907056
# 28                       52.175382                                58.948992
# 29                       52.105516                                56.990927
# 30                       60.299162                                24.547984
# 31                       59.279916                                23.145968
# 32                       58.358808                                21.743952
# 33                       57.526387                                20.341935
# 34                       56.774114                                18.939919
# 35                       80.855468                                 3.119960
# 36                       81.010936                                 3.000715
# 37                       81.166404                                 2.881470
# 38                       81.321873                                 2.762225
# 39                       81.477341                                 2.642980
# 40                       78.409331                                -1.325403
# 41                       78.599520                                -2.718988
# 42                       78.781567                                -4.112573
# 43                       78.955473                                -5.506158
# 44                       79.121238                                -6.899743
# 45                       84.762629                                 1.328226
# 46                       84.948173                                 1.232020
# 47                       85.133717                                 1.135814
# 48                       85.319262                                 1.039608
# 49                       85.504806                                 0.943402
#
#     infant_mortality_rate_ARIMA  child_mortality_rate_Linear Regression  \
# 0                      8.300000                                7.439113
# 1                      8.000000                                6.831067
# 2                      7.700000                                6.223021
# 3                      7.400000                                5.614974
# 4                      7.100000                                5.006928
# 5                     12.921611                                4.162500
# 6                     13.130852                                2.611932
# 7                     13.427721                                1.061364
# 8                     13.812220                               -0.489205
# 9                     14.284348                               -2.039773
# 10                     3.322080                                3.069960
# 11                     3.358341                                2.938783
# 12                     3.408785                                2.807606
# 13                     3.473410                                2.676430
# 14                     3.552218                                2.545253
# 15                     3.039819                                2.840121
# 16                     3.002119                                2.704106
# 17                     2.960234                                2.568090
# 18                     2.929555                                2.432075
# 19                     2.906353                                2.296059
# 20                     3.800000                                1.652621
# 21                     3.800000                                1.223992
# 22                     3.800000                                0.795363
# 23                     3.800000                                0.366734
# 24                     3.800000                               -0.061895
# 25                    68.496870                               99.764315
# 26                    66.301465                               96.153629
# 27                    63.937651                               92.542944
# 28                    61.440609                               88.932258
# 29                    58.854374                               85.321573
# 30                    30.095684                               30.236694
# 31                    29.029570                               27.579069
# 32                    27.801049                               24.921444
# 33                    26.419363                               22.263820
# 34                    24.902745                               19.606195
# 35                     3.500000                                3.585685
# 36                     3.400000                                3.441826
# 37                     3.300000                                3.297966
# 38                     3.200000                                3.154106
# 39                     3.100000                                3.010246
# 40                     4.711206                               -1.100000
# 41                     4.320178                               -2.803409
# 42                     3.927385                               -4.506818
# 43                     3.533199                               -6.210227
# 44                     3.137914                               -7.913636
# 45                     1.768453                                1.763105
# 46                     1.740576                                1.627914
# 47                     1.716368                                1.492724
# 48                     1.695831                                1.357533
# 49                     1.678963                                1.222342
#
#     child_mortality_rate_ARIMA  female_percentage_in_labor_Linear Regression  \
# 0                     9.400000                                     52.849785
# 1                     9.100000                                     53.278070
# 2                     8.800000                                     53.706355
# 3                     8.500000                                     54.134639
# 4                     8.200000                                     54.562924
# 5                    14.181899                                     55.652378
# 6                    14.155813                                     55.804151
# 7                    14.222136                                     55.955923
# 8                    14.380866                                     56.107695
# 9                    14.632005                                     56.259468
# 10                    4.033565                                     52.633359
# 11                    3.955864                                     52.796473
# 12                    3.881944                                     52.959588
# 13                    3.806755                                     53.122703
# 14                    3.731993                                     53.285817
# 15                    3.496034                                     57.098008
# 16                    3.509788                                     57.440192
# 17                    3.502651                                     57.782376
# 18                    3.432147                                     58.124561
# 19                    3.444104                                     58.466745
# 20                    4.400000                                     45.072683
# 21                    4.400000                                     44.704049
# 22                    4.400000                                     44.335416
# 23                    4.400000                                     43.966783
# 24                    4.400000                                     43.598149
# 25                  106.910288                                     58.659861
# 26                  102.845706                                     59.202573
# 27                   98.451631                                     59.745286
# 28                   93.795610                                     60.287998
# 29                   88.962649                                     60.830711
# 30                   40.611259                                     64.923201
# 31                   39.107243                                     64.823696
# 32                   37.373126                                     64.724191
# 33                   35.406239                                     64.624686
# 34                   33.215887                                     64.525182
# 35                    4.145893                                     58.708687
# 36                    4.106708                                     58.922369
# 37                    4.074911                                     59.136051
# 38                    4.056854                                     59.349733
# 39                    4.057809                                     59.563415
# 40                    6.540143                                     57.998667
# 41                    6.101574                                     57.534167
# 42                    5.682522                                     57.069667
# 43                    5.281363                                     56.605167
# 44                    4.896612                                     56.140667
# 45                    2.200000                                     50.517188
# 46                    2.100000                                     50.560540
# 47                    2.000000                                     50.603892
# 48                    1.900000                                     50.647244
# 49                    1.800000                                     50.690597
#
#     female_percentage_in_labor_ARIMA
# 0                          49.339462
# 1                          50.868659
# 2                          50.917447
# 3                          51.787144
# 4                          52.201635
# 5                          52.333358
# 6                          52.301112
# 7                          52.274881
# 8                          52.253543
# 9                          52.236186
# 10                         52.020993
# 11                         52.185720
# 12                         52.350446
# 13                         52.515172
# 14                         52.679898
# 15                         56.096599
# 16                         56.404169
# 17                         56.711738
# 18                         57.019308
# 19                         57.326878
# 20                         50.582000
# 21                         50.582000
# 22                         50.582000
# 23                         50.582000
# 24                         50.582000
# 25                         50.844800
# 26                         50.844800
# 27                         50.844800
# 28                         50.844800
# 29                         50.844800
# 30                         65.872199
# 31                         65.872165
# 32                         65.872132
# 33                         65.872099
# 34                         65.872065
# 35                         58.553935
# 36                         58.744871
# 37                         58.935806
# 38                         59.126742
# 39                         59.317677
# 40                         68.217667
# 41                         68.217667
# 42                         68.217667
# 43                         68.217667
# 44                         68.217667
# 45                         53.957713
# 46                         53.868940
# 47                         53.782756
# 48                         53.699087
# 49                         53.617860
#
# [50 rows x 32 columns]

# %%
arima_models_info
# Out:
# {('Argentina', 'total_fertility_rate'): 'ARIMA(0, 1, 2)',
#  ('Argentina', 'gdp_2015_dollar'): 'ARIMA(0, 1, 0)',
#  ('Argentina', 'gdp_per_capita_2015_dollar'): 'ARIMA(0, 1, 0)',
#  ('Argentina', 'gdp_growth'): 'ARIMA(0, 0, 0)',
#  ('Argentina', 'physicians_per_1000'): 'ARIMA(1, 0, 0)',
#  ('Argentina', 'hospital_beds_per_1000'): 'ARIMA(1, 0, 0)',
#  ('Argentina', 'arable_land_hectare_per_person'): 'ARIMA(0, 1, 0)',
#  ('Argentina', 'cpi'): 'Brak danych do modelowania',
#  ('Argentina', 'crop_production_index'): 'ARIMA(2, 1, 2)',
#  ('Argentina', 'food_production_index'): 'ARIMA(2, 1, 0)',
#  ('Argentina', 'percent_of_household_expenditure_in_gdp'): 'ARIMA(0, 1, 0)',
#  ('Argentina', 'life_expectancy_at_birth'): 'ARIMA(0, 1, 0)',
#  ('Argentina', 'infant_mortality_rate'): 'ARIMA(0, 2, 0)',
#  ('Argentina', 'child_mortality_rate'): 'ARIMA(0, 2, 0)',
#  ('Argentina', 'female_percentage_in_labor'): 'ARIMA(1, 1, 0)',
#  ('Brazil', 'total_fertility_rate'): 'ARIMA(0, 2, 1)',
#  ('Brazil', 'gdp_2015_dollar'): 'ARIMA(0, 1, 0)',
#  ('Brazil', 'gdp_per_capita_2015_dollar'): 'ARIMA(0, 1, 0)',
#  ('Brazil', 'gdp_growth'): 'ARIMA(0, 0, 0)',
#  ('Brazil', 'physicians_per_1000'): 'ARIMA(0, 1, 0)',
#  ('Brazil', 'hospital_beds_per_1000'): 'ARIMA(0, 1, 0)',
#  ('Brazil', 'arable_land_hectare_per_person'): 'ARIMA(4, 0, 1)',
#  ('Brazil', 'cpi'): 'ARIMA(0, 1, 1)',
#  ('Brazil', 'crop_production_index'): 'ARIMA(1, 1, 0)',
#  ('Brazil', 'food_production_index'): 'ARIMA(1, 1, 2)',
#  ('Brazil', 'percent_of_household_expenditure_in_gdp'): 'ARIMA(1, 0, 4)',
#  ('Brazil', 'life_expectancy_at_birth'): 'ARIMA(0, 2, 0)',
#  ('Brazil', 'infant_mortality_rate'): 'ARIMA(0, 2, 1)',
#  ('Brazil', 'child_mortality_rate'): 'ARIMA(0, 2, 2)',
#  ('Brazil', 'female_percentage_in_labor'): 'ARIMA(1, 0, 0)',
#  ('France', 'total_fertility_rate'): 'ARIMA(0, 1, 0)',
#  ('France', 'gdp_2015_dollar'): 'ARIMA(0, 1, 0)',
#  ('France', 'gdp_per_capita_2015_dollar'): 'ARIMA(0, 1, 0)',
#  ('France', 'gdp_growth'): 'ARIMA(0, 0, 0)',
#  ('France', 'physicians_per_1000'): 'ARIMA(1, 0, 0)',
#  ('France', 'hospital_beds_per_1000'): 'ARIMA(0, 1, 1)',
#  ('France', 'arable_land_hectare_per_person'): 'ARIMA(0, 1, 0)',
#  ('France', 'cpi'): 'ARIMA(0, 1, 1)',
#  ('France', 'crop_production_index'): 'ARIMA(2, 0, 2)',
#  ('France', 'food_production_index'): 'ARIMA(1, 0, 0)',
#  ('France', 'percent_of_household_expenditure_in_gdp'): 'ARIMA(1, 0, 0)',
#  ('France', 'life_expectancy_at_birth'): 'ARIMA(1, 1, 0)',
#  ('France', 'infant_mortality_rate'): 'ARIMA(0, 2, 1)',
#  ('France', 'child_mortality_rate'): 'ARIMA(1, 2, 0)',
#  ('France', 'female_percentage_in_labor'): 'ARIMA(0, 1, 1)',
#  ('Germany', 'total_fertility_rate'): 'ARIMA(0, 1, 0)',
#  ('Germany', 'gdp_2015_dollar'): 'ARIMA(0, 1, 0)',
#  ('Germany', 'gdp_per_capita_2015_dollar'): 'ARIMA(0, 1, 0)',
#  ('Germany', 'gdp_growth'): 'ARIMA(0, 0, 0)',
#  ('Germany', 'physicians_per_1000'): 'ARIMA(1, 1, 0)',
#  ('Germany', 'hospital_beds_per_1000'): 'ARIMA(0, 2, 0)',
#  ('Germany', 'arable_land_hectare_per_person'): 'ARIMA(0, 0, 3)',
#  ('Germany', 'cpi'): 'ARIMA(0, 1, 1)',
#  ('Germany', 'crop_production_index'): 'ARIMA(1, 0, 0)',
#  ('Germany', 'food_production_index'): 'ARIMA(0, 1, 0)',
#  ('Germany', 'percent_of_household_expenditure_in_gdp'): 'ARIMA(0, 1, 0)',
#  ('Germany', 'life_expectancy_at_birth'): 'ARIMA(2, 2, 0)',
#  ('Germany', 'infant_mortality_rate'): 'ARIMA(2, 2, 2)',
#  ('Germany', 'child_mortality_rate'): 'ARIMA(2, 2, 2)',
#  ('Germany', 'female_percentage_in_labor'): 'ARIMA(0, 1, 1)',
#  ('Poland', 'total_fertility_rate'): 'ARIMA(1, 2, 0)',
#  ('Poland', 'gdp_2015_dollar'): 'ARIMA(1, 2, 0)',
#  ('Poland', 'gdp_per_capita_2015_dollar'): 'ARIMA(3, 2, 0)',
#  ('Poland', 'gdp_growth'): 'ARIMA(0, 0, 0)',
#  ('Poland', 'physicians_per_1000'): 'ARIMA(1, 0, 0)',
#  ('Poland', 'hospital_beds_per_1000'): 'ARIMA(0, 1, 0)',
#  ('Poland', 'arable_land_hectare_per_person'): 'ARIMA(0, 1, 0)',
#  ('Poland', 'cpi'): 'ARIMA(0, 2, 0)',
#  ('Poland', 'crop_production_index'): 'ARIMA(0, 0, 3)',
#  ('Poland', 'food_production_index'): 'ARIMA(1, 0, 2)',
#  ('Poland', 'percent_of_household_expenditure_in_gdp'): 'ARIMA(0, 1, 0)',
#  ('Poland', 'life_expectancy_at_birth'): 'ARIMA(1, 1, 1)',
#  ('Poland', 'infant_mortality_rate'): 'ARIMA(0, 2, 0)',
#  ('Poland', 'child_mortality_rate'): 'ARIMA(1, 2, 0)',
#  ('Poland', 'female_percentage_in_labor'): 'ARIMA(0, 1, 0)',
#  ('Nigeria', 'total_fertility_rate'): 'ARIMA(1, 1, 1)',
#  ('Nigeria', 'gdp_2015_dollar'): 'ARIMA(0, 1, 0)',
#  ('Nigeria', 'gdp_per_capita_2015_dollar'): 'ARIMA(1, 1, 0)',
#  ('Nigeria', 'gdp_growth'): 'ARIMA(2, 0, 1)',
#  ('Nigeria', 'physicians_per_1000'): 'ARIMA(0, 1, 0)',
#  ('Nigeria', 'hospital_beds_per_1000'): 'ARIMA(0, 0, 0)',
#  ('Nigeria', 'arable_land_hectare_per_person'): 'ARIMA(2, 2, 2)',
#  ('Nigeria', 'cpi'): 'ARIMA(0, 2, 1)',
#  ('Nigeria', 'crop_production_index'): 'ARIMA(1, 1, 2)',
#  ('Nigeria', 'food_production_index'): 'ARIMA(1, 1, 2)',
#  ('Nigeria',
#   'percent_of_household_expenditure_in_gdp'): 'Brak danych do modelowania',
#  ('Nigeria', 'life_expectancy_at_birth'): 'ARIMA(1, 1, 0)',
#  ('Nigeria', 'infant_mortality_rate'): 'ARIMA(2, 1, 1)',
#  ('Nigeria', 'child_mortality_rate'): 'ARIMA(2, 1, 2)',
#  ('Nigeria', 'female_percentage_in_labor'): 'ARIMA(0, 0, 0)',
#  ('Kenya', 'total_fertility_rate'): 'ARIMA(2, 1, 0)',
#  ('Kenya', 'gdp_2015_dollar'): 'ARIMA(0, 2, 0)',
#  ('Kenya', 'gdp_per_capita_2015_dollar'): 'ARIMA(0, 2, 1)',
#  ('Kenya', 'gdp_growth'): 'ARIMA(0, 1, 0)',
#  ('Kenya', 'physicians_per_1000'): 'ARIMA(0, 1, 1)',
#  ('Kenya', 'hospital_beds_per_1000'): 'ARIMA(0, 0, 0)',
#  ('Kenya', 'arable_land_hectare_per_person'): 'ARIMA(0, 1, 1)',
#  ('Kenya', 'cpi'): 'ARIMA(2, 2, 0)',
#  ('Kenya', 'crop_production_index'): 'ARIMA(1, 1, 0)',
#  ('Kenya', 'food_production_index'): 'ARIMA(0, 1, 0)',
#  ('Kenya', 'percent_of_household_expenditure_in_gdp'): 'ARIMA(1, 0, 1)',
#  ('Kenya', 'life_expectancy_at_birth'): 'ARIMA(1, 1, 0)',
#  ('Kenya', 'infant_mortality_rate'): 'ARIMA(2, 1, 2)',
#  ('Kenya', 'child_mortality_rate'): 'ARIMA(2, 1, 1)',
#  ('Kenya', 'female_percentage_in_labor'): 'ARIMA(1, 0, 1)',
#  ('United Kingdom', 'total_fertility_rate'): 'ARIMA(2, 0, 2)',
#  ('United Kingdom', 'gdp_2015_dollar'): 'ARIMA(0, 1, 0)',
#  ('United Kingdom', 'gdp_per_capita_2015_dollar'): 'ARIMA(0, 1, 0)',
#  ('United Kingdom', 'gdp_growth'): 'ARIMA(0, 0, 0)',
#  ('United Kingdom', 'physicians_per_1000'): 'ARIMA(1, 1, 0)',
#  ('United Kingdom', 'hospital_beds_per_1000'): 'ARIMA(3, 2, 1)',
#  ('United Kingdom', 'arable_land_hectare_per_person'): 'ARIMA(0, 1, 0)',
#  ('United Kingdom', 'cpi'): 'ARIMA(0, 1, 1)',
#  ('United Kingdom', 'crop_production_index'): 'ARIMA(0, 0, 0)',
#  ('United Kingdom', 'food_production_index'): 'ARIMA(1, 0, 1)',
#  ('United Kingdom',
#   'percent_of_household_expenditure_in_gdp'): 'ARIMA(0, 1, 0)',
#  ('United Kingdom', 'life_expectancy_at_birth'): 'ARIMA(0, 1, 0)',
#  ('United Kingdom', 'infant_mortality_rate'): 'ARIMA(1, 2, 0)',
#  ('United Kingdom', 'child_mortality_rate'): 'ARIMA(2, 2, 2)',
#  ('United Kingdom', 'female_percentage_in_labor'): 'ARIMA(0, 1, 0)',
#  ('China', 'total_fertility_rate'): 'ARIMA(3, 0, 0)',
#  ('China', 'gdp_2015_dollar'): 'ARIMA(0, 2, 0)',
#  ('China', 'gdp_per_capita_2015_dollar'): 'ARIMA(1, 2, 1)',
#  ('China', 'gdp_growth'): 'ARIMA(2, 0, 0)',
#  ('China', 'physicians_per_1000'): 'ARIMA(0, 2, 1)',
#  ('China', 'hospital_beds_per_1000'): 'ARIMA(0, 2, 1)',
#  ('China', 'arable_land_hectare_per_person'): 'ARIMA(1, 1, 0)',
#  ('China', 'cpi'): 'ARIMA(1, 1, 1)',
#  ('China', 'crop_production_index'): 'ARIMA(1, 1, 0)',
#  ('China', 'food_production_index'): 'ARIMA(0, 1, 0)',
#  ('China', 'percent_of_household_expenditure_in_gdp'): 'ARIMA(1, 1, 0)',
#  ('China', 'life_expectancy_at_birth'): 'ARIMA(0, 2, 1)',
#  ('China', 'infant_mortality_rate'): 'ARIMA(1, 2, 2)',
#  ('China', 'child_mortality_rate'): 'ARIMA(1, 2, 2)',
#  ('China', 'female_percentage_in_labor'): 'ARIMA(0, 0, 0)',
#  ('Japan', 'total_fertility_rate'): 'ARIMA(1, 0, 2)',
#  ('Japan', 'gdp_2015_dollar'): 'ARIMA(0, 1, 0)',
#  ('Japan', 'gdp_per_capita_2015_dollar'): 'ARIMA(0, 1, 0)',
#  ('Japan', 'gdp_growth'): 'ARIMA(0, 0, 0)',
#  ('Japan', 'physicians_per_1000'): 'ARIMA(1, 1, 0)',
#  ('Japan', 'hospital_beds_per_1000'): 'ARIMA(2, 2, 0)',
#  ('Japan', 'arable_land_hectare_per_person'): 'ARIMA(0, 2, 0)',
#  ('Japan', 'cpi'): 'ARIMA(2, 0, 0)',
#  ('Japan', 'crop_production_index'): 'ARIMA(1, 1, 1)',
#  ('Japan', 'food_production_index'): 'ARIMA(2, 1, 2)',
#  ('Japan', 'percent_of_household_expenditure_in_gdp'): 'ARIMA(0, 1, 0)',
#  ('Japan', 'life_expectancy_at_birth'): 'ARIMA(0, 1, 1)',
#  ('Japan', 'infant_mortality_rate'): 'ARIMA(0, 2, 1)',
#  ('Japan', 'child_mortality_rate'): 'ARIMA(1, 2, 0)',
#  ('Japan', 'female_percentage_in_labor'): 'ARIMA(1, 0, 1)'}

# %% [markdown]
# ### WYKRESY

# %%
variables = [
    'total_fertility_rate', 'gdp_2015_dollar', 'gdp_per_capita_2015_dollar',
    'gdp_growth', 'physicians_per_1000', 'hospital_beds_per_1000',
    'arable_land_hectare_per_person', 'cpi', 'crop_production_index',
    'food_production_index', 'percent_of_household_expenditure_in_gdp',
    'life_expectancy_at_birth', 'infant_mortality_rate',
    'child_mortality_rate', 'female_percentage_in_labor'
]

# %%
from docx import Document
from docx.shared import Inches
import os
import matplotlib.pyplot as plt

# Folder temp do zapisywania wykresów
temp_folder = "temp_images"
os.makedirs(temp_folder, exist_ok=True)

doc = Document()
doc.add_heading('Raport z wynikami', level=1)

def plot_pred_and_save_to_doc(country_name, hist_full_df, pred_full_df, variables, arima_info):
    hist_df = hist_full_df[hist_full_df['country_name'] == country_name]
    pred_df = pred_full_df[pred_full_df['country_name'] == country_name]

    for var in variables:
        arima_details = arima_info.get((country_name, var), "BRAK modelu ARIMA")
        doc.add_heading(f"Kraj: {country_name}, Zmienna: {var}", level=2)
        doc.add_paragraph(f"Model: {arima_details}")
        #print(f"Kraj: {country_name}, Zmienna: {var} -> {arima_details}")
        plt.figure(figsize=(10, 6))
        
        plt.plot(
            hist_df['year'], 
            hist_df[var], 
            label=f'Dane', 
            marker='o', color='blue', linestyle='-'
        )
        
        #KMNK
        plt.plot(
            pred_df['year'], 
            pred_df[f'{var}_Linear Regression'], 
            label=f'Prognoza KMNK', 
            marker='o', color='green', linestyle='-'
        )

        #ARIMA
        arima_label = f'Prognoza ARIMA'
        if pred_df[f'{var}_ARIMA'].isnull().all():
            arima_label += ' - BRAK'

        plt.plot(
            pred_df['year'], 
            pred_df[f'{var}_ARIMA'], 
            label=arima_label, 
            marker='o', color='orange', linestyle='-'
        )
        
        plt.title(f'Dane historyczne i prognozy: {var} ({country_name})')
        plt.xlabel('Rok')
        plt.ylabel(var)
        plt.legend()
        plt.grid()
        
        # Zapis wykresu
        image_path = os.path.join(temp_folder, f"{country_name}_{var}.png")
        plt.savefig(image_path, format='png', bbox_inches='tight')
        plt.close()
        doc.add_picture(image_path, width=Inches(6))


for country in countries:
    plot_pred_and_save_to_doc(
        country_name=country, 
        hist_full_df=df, 
        pred_full_df=forecast_df, 
        variables=variables, 
        arima_info=arima_models_info
    )

# Zapis dokumentu
output_file = "raport.docx"
doc.save(output_file)

# Usunięcie plików tymczasowych
for file in os.listdir(temp_folder):
    os.remove(os.path.join(temp_folder, file))
os.rmdir(temp_folder)

print(f"Raport zapisano do pliku: {output_file}")
# Out:
# Kraj: Argentina, Zmienna: total_fertility_rate -> ARIMA(0, 1, 2)
# Kraj: Argentina, Zmienna: gdp_2015_dollar -> ARIMA(0, 1, 0)
# Kraj: Argentina, Zmienna: gdp_per_capita_2015_dollar -> ARIMA(0, 1, 0)
# Kraj: Argentina, Zmienna: gdp_growth -> ARIMA(0, 0, 0)
# Kraj: Argentina, Zmienna: physicians_per_1000 -> ARIMA(1, 0, 0)
# Kraj: Argentina, Zmienna: hospital_beds_per_1000 -> ARIMA(1, 0, 0)
# Kraj: Argentina, Zmienna: arable_land_hectare_per_person -> ARIMA(0, 1, 0)
# Kraj: Argentina, Zmienna: cpi -> Brak danych do modelowania
# Kraj: Argentina, Zmienna: crop_production_index -> ARIMA(2, 1, 2)
# Kraj: Argentina, Zmienna: food_production_index -> ARIMA(2, 1, 0)
# Kraj: Argentina, Zmienna: percent_of_household_expenditure_in_gdp -> ARIMA(0, 1, 0)
# Kraj: Argentina, Zmienna: life_expectancy_at_birth -> ARIMA(0, 1, 0)
# Kraj: Argentina, Zmienna: infant_mortality_rate -> ARIMA(0, 2, 0)
# Kraj: Argentina, Zmienna: child_mortality_rate -> ARIMA(0, 2, 0)
# Kraj: Argentina, Zmienna: female_percentage_in_labor -> ARIMA(1, 1, 0)
# Kraj: Brazil, Zmienna: total_fertility_rate -> ARIMA(0, 2, 1)
# Kraj: Brazil, Zmienna: gdp_2015_dollar -> ARIMA(0, 1, 0)
# Kraj: Brazil, Zmienna: gdp_per_capita_2015_dollar -> ARIMA(0, 1, 0)
# Kraj: Brazil, Zmienna: gdp_growth -> ARIMA(0, 0, 0)
# Kraj: Brazil, Zmienna: physicians_per_1000 -> ARIMA(0, 1, 0)
# Kraj: Brazil, Zmienna: hospital_beds_per_1000 -> ARIMA(0, 1, 0)
# Kraj: Brazil, Zmienna: arable_land_hectare_per_person -> ARIMA(4, 0, 1)
# Kraj: Brazil, Zmienna: cpi -> ARIMA(0, 1, 1)
# Kraj: Brazil, Zmienna: crop_production_index -> ARIMA(1, 1, 0)
# Kraj: Brazil, Zmienna: food_production_index -> ARIMA(1, 1, 2)
# Kraj: Brazil, Zmienna: percent_of_household_expenditure_in_gdp -> ARIMA(1, 0, 4)
# Kraj: Brazil, Zmienna: life_expectancy_at_birth -> ARIMA(0, 2, 0)
# Kraj: Brazil, Zmienna: infant_mortality_rate -> ARIMA(0, 2, 1)
# Kraj: Brazil, Zmienna: child_mortality_rate -> ARIMA(0, 2, 2)
# Kraj: Brazil, Zmienna: female_percentage_in_labor -> ARIMA(1, 0, 0)
# Kraj: France, Zmienna: total_fertility_rate -> ARIMA(0, 1, 0)
# Kraj: France, Zmienna: gdp_2015_dollar -> ARIMA(0, 1, 0)
# Kraj: France, Zmienna: gdp_per_capita_2015_dollar -> ARIMA(0, 1, 0)
# Kraj: France, Zmienna: gdp_growth -> ARIMA(0, 0, 0)
# Kraj: France, Zmienna: physicians_per_1000 -> ARIMA(1, 0, 0)
# Kraj: France, Zmienna: hospital_beds_per_1000 -> ARIMA(0, 1, 1)
# Kraj: France, Zmienna: arable_land_hectare_per_person -> ARIMA(0, 1, 0)
# Kraj: France, Zmienna: cpi -> ARIMA(0, 1, 1)
# Kraj: France, Zmienna: crop_production_index -> ARIMA(2, 0, 2)
# Kraj: France, Zmienna: food_production_index -> ARIMA(1, 0, 0)
# Kraj: France, Zmienna: percent_of_household_expenditure_in_gdp -> ARIMA(1, 0, 0)
# Kraj: France, Zmienna: life_expectancy_at_birth -> ARIMA(1, 1, 0)
# Kraj: France, Zmienna: infant_mortality_rate -> ARIMA(0, 2, 1)
# Kraj: France, Zmienna: child_mortality_rate -> ARIMA(1, 2, 0)
# Kraj: France, Zmienna: female_percentage_in_labor -> ARIMA(0, 1, 1)
# Kraj: Germany, Zmienna: total_fertility_rate -> ARIMA(0, 1, 0)
# Kraj: Germany, Zmienna: gdp_2015_dollar -> ARIMA(0, 1, 0)
# Kraj: Germany, Zmienna: gdp_per_capita_2015_dollar -> ARIMA(0, 1, 0)
# Kraj: Germany, Zmienna: gdp_growth -> ARIMA(0, 0, 0)
# Kraj: Germany, Zmienna: physicians_per_1000 -> ARIMA(1, 1, 0)
# Kraj: Germany, Zmienna: hospital_beds_per_1000 -> ARIMA(0, 2, 0)
# Kraj: Germany, Zmienna: arable_land_hectare_per_person -> ARIMA(0, 0, 3)
# Kraj: Germany, Zmienna: cpi -> ARIMA(0, 1, 1)
# Kraj: Germany, Zmienna: crop_production_index -> ARIMA(1, 0, 0)
# Kraj: Germany, Zmienna: food_production_index -> ARIMA(0, 1, 0)
# Kraj: Germany, Zmienna: percent_of_household_expenditure_in_gdp -> ARIMA(0, 1, 0)
# Kraj: Germany, Zmienna: life_expectancy_at_birth -> ARIMA(2, 2, 0)
# Kraj: Germany, Zmienna: infant_mortality_rate -> ARIMA(2, 2, 2)
# Kraj: Germany, Zmienna: child_mortality_rate -> ARIMA(2, 2, 2)
# Kraj: Germany, Zmienna: female_percentage_in_labor -> ARIMA(0, 1, 1)
# Kraj: Poland, Zmienna: total_fertility_rate -> ARIMA(1, 2, 0)
# Kraj: Poland, Zmienna: gdp_2015_dollar -> ARIMA(1, 2, 0)
# Kraj: Poland, Zmienna: gdp_per_capita_2015_dollar -> ARIMA(3, 2, 0)
# Kraj: Poland, Zmienna: gdp_growth -> ARIMA(0, 0, 0)
# Kraj: Poland, Zmienna: physicians_per_1000 -> ARIMA(1, 0, 0)
# Kraj: Poland, Zmienna: hospital_beds_per_1000 -> ARIMA(0, 1, 0)
# Kraj: Poland, Zmienna: arable_land_hectare_per_person -> ARIMA(0, 1, 0)
# Kraj: Poland, Zmienna: cpi -> ARIMA(0, 2, 0)
# Kraj: Poland, Zmienna: crop_production_index -> ARIMA(0, 0, 3)
# Kraj: Poland, Zmienna: food_production_index -> ARIMA(1, 0, 2)
# Kraj: Poland, Zmienna: percent_of_household_expenditure_in_gdp -> ARIMA(0, 1, 0)
# Kraj: Poland, Zmienna: life_expectancy_at_birth -> ARIMA(1, 1, 1)
# Kraj: Poland, Zmienna: infant_mortality_rate -> ARIMA(0, 2, 0)
# Kraj: Poland, Zmienna: child_mortality_rate -> ARIMA(1, 2, 0)
# Kraj: Poland, Zmienna: female_percentage_in_labor -> ARIMA(0, 1, 0)
# Kraj: Nigeria, Zmienna: total_fertility_rate -> ARIMA(1, 1, 1)
# Kraj: Nigeria, Zmienna: gdp_2015_dollar -> ARIMA(0, 1, 0)
# Kraj: Nigeria, Zmienna: gdp_per_capita_2015_dollar -> ARIMA(1, 1, 0)
# Kraj: Nigeria, Zmienna: gdp_growth -> ARIMA(2, 0, 1)
# Kraj: Nigeria, Zmienna: physicians_per_1000 -> ARIMA(0, 1, 0)
# Kraj: Nigeria, Zmienna: hospital_beds_per_1000 -> ARIMA(0, 0, 0)
# Kraj: Nigeria, Zmienna: arable_land_hectare_per_person -> ARIMA(2, 2, 2)
# Kraj: Nigeria, Zmienna: cpi -> ARIMA(0, 2, 1)
# Kraj: Nigeria, Zmienna: crop_production_index -> ARIMA(1, 1, 2)
# Kraj: Nigeria, Zmienna: food_production_index -> ARIMA(1, 1, 2)
# Kraj: Nigeria, Zmienna: percent_of_household_expenditure_in_gdp -> Brak danych do modelowania
# Kraj: Nigeria, Zmienna: life_expectancy_at_birth -> ARIMA(1, 1, 0)
# Kraj: Nigeria, Zmienna: infant_mortality_rate -> ARIMA(2, 1, 1)
# Kraj: Nigeria, Zmienna: child_mortality_rate -> ARIMA(2, 1, 2)
# Kraj: Nigeria, Zmienna: female_percentage_in_labor -> ARIMA(0, 0, 0)
# Kraj: Kenya, Zmienna: total_fertility_rate -> ARIMA(2, 1, 0)
# Kraj: Kenya, Zmienna: gdp_2015_dollar -> ARIMA(0, 2, 0)
# Kraj: Kenya, Zmienna: gdp_per_capita_2015_dollar -> ARIMA(0, 2, 1)
# Kraj: Kenya, Zmienna: gdp_growth -> ARIMA(0, 1, 0)
# Kraj: Kenya, Zmienna: physicians_per_1000 -> ARIMA(0, 1, 1)
# Kraj: Kenya, Zmienna: hospital_beds_per_1000 -> ARIMA(0, 0, 0)
# Kraj: Kenya, Zmienna: arable_land_hectare_per_person -> ARIMA(0, 1, 1)
# Kraj: Kenya, Zmienna: cpi -> ARIMA(2, 2, 0)
# Kraj: Kenya, Zmienna: crop_production_index -> ARIMA(1, 1, 0)
# Kraj: Kenya, Zmienna: food_production_index -> ARIMA(0, 1, 0)
# Kraj: Kenya, Zmienna: percent_of_household_expenditure_in_gdp -> ARIMA(1, 0, 1)
# Kraj: Kenya, Zmienna: life_expectancy_at_birth -> ARIMA(1, 1, 0)
# Kraj: Kenya, Zmienna: infant_mortality_rate -> ARIMA(2, 1, 2)
# Kraj: Kenya, Zmienna: child_mortality_rate -> ARIMA(2, 1, 1)
# Kraj: Kenya, Zmienna: female_percentage_in_labor -> ARIMA(1, 0, 1)
# Kraj: United Kingdom, Zmienna: total_fertility_rate -> ARIMA(2, 0, 2)
# Kraj: United Kingdom, Zmienna: gdp_2015_dollar -> ARIMA(0, 1, 0)
# Kraj: United Kingdom, Zmienna: gdp_per_capita_2015_dollar -> ARIMA(0, 1, 0)
# Kraj: United Kingdom, Zmienna: gdp_growth -> ARIMA(0, 0, 0)
# Kraj: United Kingdom, Zmienna: physicians_per_1000 -> ARIMA(1, 1, 0)
# Kraj: United Kingdom, Zmienna: hospital_beds_per_1000 -> ARIMA(3, 2, 1)
# Kraj: United Kingdom, Zmienna: arable_land_hectare_per_person -> ARIMA(0, 1, 0)
# Kraj: United Kingdom, Zmienna: cpi -> ARIMA(0, 1, 1)
# Kraj: United Kingdom, Zmienna: crop_production_index -> ARIMA(0, 0, 0)
# Kraj: United Kingdom, Zmienna: food_production_index -> ARIMA(1, 0, 1)
# Kraj: United Kingdom, Zmienna: percent_of_household_expenditure_in_gdp -> ARIMA(0, 1, 0)
# Kraj: United Kingdom, Zmienna: life_expectancy_at_birth -> ARIMA(0, 1, 0)
# Kraj: United Kingdom, Zmienna: infant_mortality_rate -> ARIMA(1, 2, 0)
# Kraj: United Kingdom, Zmienna: child_mortality_rate -> ARIMA(2, 2, 2)
# Kraj: United Kingdom, Zmienna: female_percentage_in_labor -> ARIMA(0, 1, 0)
# Kraj: China, Zmienna: total_fertility_rate -> ARIMA(3, 0, 0)
# Kraj: China, Zmienna: gdp_2015_dollar -> ARIMA(0, 2, 0)
# Kraj: China, Zmienna: gdp_per_capita_2015_dollar -> ARIMA(1, 2, 1)
# Kraj: China, Zmienna: gdp_growth -> ARIMA(2, 0, 0)
# Kraj: China, Zmienna: physicians_per_1000 -> ARIMA(0, 2, 1)
# Kraj: China, Zmienna: hospital_beds_per_1000 -> ARIMA(0, 2, 1)
# Kraj: China, Zmienna: arable_land_hectare_per_person -> ARIMA(1, 1, 0)
# Kraj: China, Zmienna: cpi -> ARIMA(1, 1, 1)
# Kraj: China, Zmienna: crop_production_index -> ARIMA(1, 1, 0)
# Kraj: China, Zmienna: food_production_index -> ARIMA(0, 1, 0)
# Kraj: China, Zmienna: percent_of_household_expenditure_in_gdp -> ARIMA(1, 1, 0)
# Kraj: China, Zmienna: life_expectancy_at_birth -> ARIMA(0, 2, 1)
# Kraj: China, Zmienna: infant_mortality_rate -> ARIMA(1, 2, 2)
# Kraj: China, Zmienna: child_mortality_rate -> ARIMA(1, 2, 2)
# Kraj: China, Zmienna: female_percentage_in_labor -> ARIMA(0, 0, 0)
# Kraj: Japan, Zmienna: total_fertility_rate -> ARIMA(1, 0, 2)
# Kraj: Japan, Zmienna: gdp_2015_dollar -> ARIMA(0, 1, 0)
# Kraj: Japan, Zmienna: gdp_per_capita_2015_dollar -> ARIMA(0, 1, 0)
# Kraj: Japan, Zmienna: gdp_growth -> ARIMA(0, 0, 0)
# Kraj: Japan, Zmienna: physicians_per_1000 -> ARIMA(1, 1, 0)
# Kraj: Japan, Zmienna: hospital_beds_per_1000 -> ARIMA(2, 2, 0)
# Kraj: Japan, Zmienna: arable_land_hectare_per_person -> ARIMA(0, 2, 0)
# Kraj: Japan, Zmienna: cpi -> ARIMA(2, 0, 0)
# Kraj: Japan, Zmienna: crop_production_index -> ARIMA(1, 1, 1)
# Kraj: Japan, Zmienna: food_production_index -> ARIMA(2, 1, 2)
# Kraj: Japan, Zmienna: percent_of_household_expenditure_in_gdp -> ARIMA(0, 1, 0)
# Kraj: Japan, Zmienna: life_expectancy_at_birth -> ARIMA(0, 1, 1)
# Kraj: Japan, Zmienna: infant_mortality_rate -> ARIMA(0, 2, 1)
# Kraj: Japan, Zmienna: child_mortality_rate -> ARIMA(1, 2, 0)
# Kraj: Japan, Zmienna: female_percentage_in_labor -> ARIMA(1, 0, 1)
# Raport zapisano do pliku: raport.docx
